# %% [markdown]
# # ArtsyCollector

# %% [markdown]
# ## Objective
# To collect artwork data from Artsy.net

# %% [markdown]
# ### 1. Scrape links for all the artworks on sale currently

# %%
# import libraries
import requests
import pprint
import lxml
from selenium import webdriver
from time import sleep

# specify the base URL
BASE_URL = "https://www.artsy.net/collect?page=1&acquireable=true&offerable=false&at_auction=false"

# launch the Selenium Chrome driver
driver = webdriver.Chrome('chrome_driver/chromedriver')
driver.get(BASE_URL)

# find the total number of pages in this search
page_nav = driver.find_elements_by_xpath('//div[@class="Box-sc-15se88d-0 iMqpar"]')
page_total = int(page_nav[-1].find_element_by_tag_name("a").text)

# specify the links data object
links = []

# start the Chrome webdriver
driver = webdriver.Chrome('chrome_driver/chromedriver')

# loop over each page
for i in range(page_total):

    # open the page with Selenium
    page_counter = i + 1
    URL = "https://www.artsy.net/collect?page=" + str(page_counter) + "&acquireable=true&offerable=false&at_auction=false"
    driver.get(URL)
    sleep(2)

    # find all the artworks on the page
    artworksOnPage = driver.find_elements_by_xpath('//div[@data-test="artworkGridItem"]')

    for entry in artworksOnPage:
        # find all the links to those artworks on the page
        links.append(entry.find_element_by_tag_name("a").get_attribute("href"))

# print the total number of links we have
print(len(links))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-7343cd7945f6> in <module>
#      28     driver = webdriver.Chrome('chrome_driver/chromedriver')
#      29     driver.get(URL)
# ---> 30     sleep(5)
#      31
#      32     # find all the artworks on the page
#
# KeyboardInterrupt:

# %%
# write the links file to a separate .txt file for backup
with open('links_list.txt', 'w') as filehandle:
    for listitem in links:
        filehandle.write('%s\n' % listitem)

# %% [markdown]
# ### 2. Scrape information from each of those artwork links with Chrome Selenium

# %%
# import libraries
import requests
import pprint
import lxml
from selenium import webdriver
from time import sleep


# define the data structure

data = {"page_URL": [], "artist": [], "artist_nationality": [], "artist_birthdate": [], "title": [], "image_URL": [], "year": [], "gallery": [], "gallery_location": [], "medium": [], "medium_details": [], "size_inches": [], "size_cm": [], "condition": [], "classification": [], "signed": [], "authenticated": [], "framed": [], "currency": [], "price": []}


# set up the Selenium driver

driver = webdriver.Chrome('chrome_driver/chromedriver')


# read the list of links

## actual
links_list = []
with open('links_list.txt', 'r') as filehandle:
    for line in filehandle:
        currentLink = line[:-1]
        links_list.append(currentLink)

## for diagnostics ONLY
links_dummy = ["https://www.artsy.net/artwork/karl-hartman-uncommon-crow", "https://www.artsy.net/artwork/hollis-dunlap-inner-dialogues", "https://www.artsy.net/artwork/jaena-kwon-red-petals"]



# loop over all entries in the links list

for index, entry in enumerate(links_list):
    print(index+1, entry)
    URL = entry
    data["page_URL"].append(URL)
    driver.get(URL)
    sleep(1)

    # extract information from image area

    image_URL = driver.find_element_by_xpath('//img[@data-type="artwork-image"]').get_attribute("src")
    data["image_URL"].append(image_URL)

    # extract information from sidebar area

    sidebar = driver.find_element_by_xpath('//div[@data-test="artworkSidebar"]').text.split("\n")

    artist = sidebar[0]
    title = sidebar[2].split(", ")[0]
    year = sidebar[2].split(", ")[1]
    medium_details = sidebar[3]
    size_inches = sidebar[4]
    size_cm = sidebar[5]
    classification = sidebar[6]
    currency = sidebar[7][0:1]
    price = sidebar[7][1:]
    gallery = sidebar[12]
    gallery_location = sidebar[13]

    data["artist"].append(sidebar[0])
    data["title"].append(sidebar[2].split(", ")[0])
    data["year"].append(sidebar[2].split(", ")[1])
    data["medium_details"].append(sidebar[3])
    data["size_inches"].append(sidebar[4])
    data["size_cm"].append(sidebar[5])
    data["classification"].append(sidebar[6])
    data["currency"].append(sidebar[7][0:1])
    data["price"].append(sidebar[7][1:])
    data["gallery"].append(sidebar[12])
    data["gallery_location"].append(sidebar[13])

    # extract information from caption area

    caption = driver.find_element_by_xpath('//div[@data-test="artworkDetails"]').text.split("\n")

    medium = ""
    if "Medium" in caption:
        index = caption.index("Medium")
        medium = caption[index+1]
    else:
        medium = "NA"
    data["medium"].append(medium)

    condition = ""
    if "Condition" in caption:
        index = caption.index("Condition")
        condition = caption[index+1]
    else:
        condition = "NA"
    data["condition"].append(condition)

    signed = ""
    if "Signature" in caption:
        index = caption.index("Signature")
        signed = caption[index+1]
    else:
        signed = "NA"
    data["signed"].append(signed)

    authenticated = ""
    if "Certificate of authenticity" in caption:
        index = caption.index("Certificate of authenticity")
        authenticated = caption[index+1]
    else:
        authenticated = "NA"
    data["authenticated"].append(authenticated)

    framed = ""
    if "Frame" in caption:
        index = caption.index("Frame")
        framed = caption[index+1]
    else:
        framed = "NA"
    data["framed"].append(framed)

    # extract information from artist bio area

    bio = driver.find_element_by_xpath('//div[@data-test="artistInfo"]').text.split("\n")
    
    artist_nationality = ""
    artist_birthdate = ""

    # if there is a birthdate
    if "b." in bio[1]:
        # if there is only a birthdate
        if bio[1][0] == "b":
            artist_nationality = "NA"
            artist_birthdate = bio[1].split("b. ")[1][0:4].translate({ord('•'): None})
        # if there is both a birthdate and a nationality
        else:
            artist_nationality = bio[1].split(", b. ")[0].translate({ord('•'): None})
            artist_birthdate = bio[1].split(", b. ")[1][0:4].translate({ord('•'): None})
    
    # if there is no birthdate
    else:
        # if there is only a nationality
        if len(bio[1]) > 0:
            artist_nationality = bio[1].translate({ord('•'): None})
            artist_birthdate = "NA"
        # if there is no birthdate or nationality
        else:
            artist_nationality = "NA"
            artist_birthdate = "NA"
    
    data["artist_nationality"].append(artist_nationality)
    data["artist_birthdate"].append(artist_birthdate)
    
    # print updated data
    print(title, artist, price, currency, artist_nationality, artist_birthdate, framed, authenticated, signed)


# quit driver and print data
driver.quit()
print(len(data["title"]))
# Out:
# 1 https://www.artsy.net/artwork/yigal-ozeri-untitled-pricilla-3
# Untitled "Pricilla" Yigal Ozeri 55,000 $ Israeli 1958 Included Included Hand-signed by artist
# 2 https://www.artsy.net/artwork/hollis-dunlap-inner-dialogues
# Inner Dialogues Hollis Dunlap 4,500 $ American 1977 Not included NA Hand-signed by artist
# 3 https://www.artsy.net/artwork/hollis-dunlap-meghan-in-summer-quarantine-nude
# Meghan in Summer (Quarantine Nude)  Hollis Dunlap 2,400 $ American 1977 Included NA Hand-signed by artist
# 158 https://www.artsy.net/artwork/elmer-guevara-that-shit-that-got-me-sick-that-one-time
# That shit that got me sick that one time Elmer Guevara 1,500 $ NA 1990 Included NA Hand-signed by artist
# 159 https://www.artsy.net/artwork/donata-minderyte-ding-dong-avon-calling
# Ding Dong! Avon Calling! Donata Minderytė 2,760 € Lithuanian 1991 Not included Included Not signed
# 160 https://www.artsy.net/artwork/william-adolphus-knell-shipping-off-the-coast
# Shipping off the Coast William Adolphus Knell 3,450 £ British, 1802–1875 NA Included NA Hand-signed by artist, Signed lower right
# 161 https://www.artsy.net/artwork/sherie-franssen-sibyls
# Sibyls Sherie' Franssen 7,500 $ American NA Included Included Hand-signed by artist
# 162 https://www.artsy.net/artwork/barbara-strasen-rococo-modo-1
# Rococo Modo Barbara Strasen 4,100 $ American NA Included Included Hand-signed by artist
# 163 https://www.artsy.net/artwork/helmut-newton-playing-with-doll-paris-feeling-naked-blue-1
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-23-b8a3028d324a> in <module>
#      42     # extract information from image area
#      43
# ---> 44     image_URL = driver.find_element_by_xpath('//img[@data-type="artwork-image"]').get_attribute("src")
#      45     data["image_URL"].append(image_URL)
#      46
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//img[@data-type="artwork-image"]"}
#   (Session info: chrome=88.0.4324.96)

# %%
from pprint import pprint
pprint(data)
# Out:
# {'artist': ['Yigal Ozeri',
#             'Hollis Dunlap',
#             'Hollis Dunlap',
#             'Karl Hartman',
#             'Josh Reames',
#             'Sophie Cohen',
#             'Luca Coser',
#             'Mia Bergeron',
#             'Hollis Dunlap',
#             'Simon Allen',
#             'KATSU',
#             'Hollis Dunlap',
#             'Karl Hartman',
#             'Hollis Dunlap',
#             'KATSU',
#             'Sara Dare',
#             'Hollis Dunlap',
#             'Kit Warren',
#             'Hollis Dunlap',
#             'Hollis Dunlap',
#             'Hollis Dunlap',
#             'Richard Orlinski',
#             'Unknown Artist',
#             'Altoon Sultan',
#             'Luca Coser',
#             'Suzanne Howes Stevens',
#             'Robert Goldstrom',
#             'Madelyn Wood',
#             'Clara Berta',
#             'Amber Goldhammer',
#             'Madelyn Wood',
#             'Kit Warren',
#             'Jaclyn Alderete',
#             'William H. Littlefield',
#             'Altoon Sultan',
#             'Aiden Kringen',
#             'Amber Goldhammer',
#             'Luca Coser',
#             'Amber Goldhammer',
#             'Hollis Dunlap',
#             'Amber Goldhammer',
#             'Peter Max',
#             'Jamie Kirkland',
#             'Peter Sandbichler',
#             'Benoit Singy',
#             'Romero Britto',
#             'Robert George',
#             'Deborah Kahn',
#             'Rob Douglas',
#             'Carlos Cruz-Diez',
#             'Giulia Abbadessa',
#             'Sylvie Joly',
#             'Alfredo Rapetti Mogol',
#             'Richard Orlinski',
#             'Jamie Kirkland',
#             'SEEN',
#             'Peter Max',
#             'MJ Lindo',
#             'Steve Cook',
#             'Rachel Hellmann',
#             'Rachel Hellmann',
#             'Karl Hartman',
#             'Peter Max',
#             'Peter Sandbichler',
#             'Peter Sandbichler',
#             'Shauna La',
#             'Andrea Landini',
#             'Luca Coser',
#             'Helen Frankenthaler',
#             'Jamie Kirkland',
#             'Bruce Rubenstein',
#             'Hollis Dunlap',
#             'Stefano Bonacci',
#             'Silvia Caimi',
#             'Robert Philipp',
#             'Jessica Libor',
#             'Eugene Berman',
#             'Alfredo Rapetti Mogol',
#             'Preston Paperboy',
#             'Balint Zsako',
#             'Sze Wai Wong',
#             'Luca Coser',
#             'Alfredo Rapetti Mogol',
#             'Robert Combas',
#             'Pablo Picasso',
#             'George Condo',
#             'Tarragon Smith',
#             'KATSU',
#             'Ksenia Kovalova',
#             'Hunt Slonem',
#             'Hyacinthe Ouattara',
#             'Keith Haring',
#             'Nobuyoshi Araki',
#             'Jack Graves III',
#             'Brandon Neher',
#             'Alexis Duque',
#             'Matt Tru',
#             'Armando de la Garza',
#             'Piero Pizzi Cannella',
#             'Hiroshi Sato',
#             'Hollis Dunlap',
#             'Peter Max',
#             'Mark di Suvero',
#             'Robert Lebsack',
#             'Alfredo Rapetti Mogol',
#             'Simon Allen',
#             'pierrick allemand',
#             'Max Gärtner',
#             'pierrick allemand',
#             'Hollis Dunlap',
#             'Jason Martin',
#             'Sam Tan Shan Cheng',
#             'Richard Hambleton',
#             'Edward Kienholz',
#             'Piero Pizzi Cannella',
#             'Jamie Kirkland',
#             'Robert George',
#             'Amber Goldhammer',
#             'Nobuyoshi Araki',
#             'Alexis Duque',
#             'Amber Goldhammer',
#             'Peter Sandbichler',
#             'Nicole Leidenfrost',
#             'Becky Yazdan',
#             'pierrick allemand',
#             'Jaena Kwon',
#             'America Martin',
#             'RISK',
#             'Tarragon Smith',
#             'Preston Paperboy',
#             'Charles Buckley',
#             'KATSU',
#             'Shen Ping',
#             'Ben Frost',
#             'Gary John',
#             'Michio Takayama',
#             'REWA',
#             'Charles Buckley',
#             'Tommy Lennartsson',
#             'Edgar Hunt',
#             'Patricia Millar',
#             "Suzy O'Mullane",
#             'Mitch McGee',
#             'Benoit Singy',
#             'Peter Mars',
#             'America Martin',
#             'Kris Gebhardt',
#             'Ruth Schloss',
#             'Elmer Guevara',
#             'Jim Dine',
#             'Linda R Cuccurullo',
#             'Joel Nuñez',
#             'August Puig',
#             'Peter Max',
#             'Jesús Matheus',
#             'Peter Max',
#             'Mark Kostabi',
#             'Elmer Guevara',
#             'Donata Minderytė',
#             'William Adolphus Knell',
#             "Sherie' Franssen",
#             'Barbara Strasen'],
#  'artist_birthdate': ['1958',
#                       '1977',
#                       '1977',
#                       'NA',
#                       '1985',
#                       'NA',
#                       '1965',
#                       'NA',
#                       '1977',
#                       '1967',
#                       '1982',
#                       '1977',
#                       'NA',
#                       '1977',
#                       '1982',
#                       'NA',
#                       '1977',
#                       'NA',
#                       '1977',
#                       '1977',
#                       '1977',
#                       '1966',
#                       'NA',
#                       '1948',
#                       '1965',
#                       'NA',
#                       '1952',
#                       '1997',
#                       'NA',
#                       '1979',
#                       '1997',
#                       'NA',
#                       'NA',
#                       'NA',
#                       '1948',
#                       'NA',
#                       '1979',
#                       '1965',
#                       '1979',
#                       '1977',
#                       '1979',
#                       '1937',
#                       'NA',
#                       '1964',
#                       '1963',
#                       '1963',
#                       'NA',
#                       'NA',
#                       'NA',
#                       'NA',
#                       'NA',
#                       'NA',
#                       '1961',
#                       '1966',
#                       'NA',
#                       '1961',
#                       '1937',
#                       'NA',
#                       'NA',
#                       'NA',
#                       'NA',
#                       'NA',
#                       '1937',
#                       '1964',
#                       '1964',
#                       '1983',
#                       'NA',
#                       '1965',
#                       'NA',
#                       'NA',
#                       '1955',
#                       '1977',
#                       '1971',
#                       'NA',
#                       'NA',
#                       '1987',
#                       'NA',
#                       '1961',
#                       'NA',
#                       '1979',
#                       '1990',
#                       '1965',
#                       '1961',
#                       '1957',
#                       'NA',
#                       '1957',
#                       'NA',
#                       '1982',
#                       '1991',
#                       '1951',
#                       '1981',
#                       'NA',
#                       '1940',
#                       '1988',
#                       '1983',
#                       '1971',
#                       '1990',
#                       '1973',
#                       '1955',
#                       '1987',
#                       '1977',
#                       '1937',
#                       '1933',
#                       '1980',
#                       '1961',
#                       '1967',
#                       '1973',
#                       '1982',
#                       '1973',
#                       '1977',
#                       '1970',
#                       '1989',
#                       'NA',
#                       'NA',
#                       '1955',
#                       'NA',
#                       'NA',
#                       '1979',
#                       '1940',
#                       '1971',
#                       '1979',
#                       '1964',
#                       '1974',
#                       '1977',
#                       '1973',
#                       '1986',
#                       '1980',
#                       '1967',
#                       'NA',
#                       'NA',
#                       '1966',
#                       '1982',
#                       '1947',
#                       'NA',
#                       '1963',
#                       'NA',
#                       '1987',
#                       '1966',
#                       '1970',
#                       'NA',
#                       'NA',
#                       '1958',
#                       'NA',
#                       '1963',
#                       '1959',
#                       '1980',
#                       '1964',
#                       'NA',
#                       '1990',
#                       '1935',
#                       'NA',
#                       '1973',
#                       'NA',
#                       '1937',
#                       '1957',
#                       '1937',
#                       '1960',
#                       '1990',
#                       '1991',
#                       'NA',
#                       'NA',
#                       'NA'],
#  'artist_nationality': ['Israeli',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'Follow',
#                         'Italian',
#                         'American',
#                         'American',
#                         'British',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'British',
#                         'American',
#                         'Follow',
#                         'American',
#                         'American',
#                         'American',
#                         'French',
#                         'Follow',
#                         'American',
#                         'Italian',
#                         'American, 1944–2017',
#                         'American',
#                         'American',
#                         'Hungarian-American',
#                         'American',
#                         'American',
#                         'Follow',
#                         'American',
#                         'American, 1902–1969',
#                         'American',
#                         'American',
#                         'American',
#                         'Italian',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'Follow',
#                         'Austrian',
#                         'Swiss',
#                         'Brazilian',
#                         'Follow',
#                         'Follow',
#                         'American, 1960–2017',
#                         'Venezuelan, 1923–2019',
#                         'Follow',
#                         'Follow',
#                         'Italian',
#                         'French',
#                         'Follow',
#                         'American',
#                         'American',
#                         'Follow',
#                         'Follow',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'Austrian',
#                         'Austrian',
#                         'US',
#                         'Italian, 1847–1935',
#                         'Italian',
#                         'American, 1928–2011',
#                         'Follow',
#                         'American',
#                         'American',
#                         'Italian',
#                         'Italian',
#                         'American, 1895–1981',
#                         'American',
#                         'American, 1899–1972',
#                         'Italian',
#                         'British',
#                         'Hungarian',
#                         'Hong Kong',
#                         'Italian',
#                         'Italian',
#                         'French',
#                         'Spanish, 1881–1973',
#                         'American',
#                         'Follow',
#                         'American',
#                         'Ukrainian',
#                         'American',
#                         'Burkina Faso',
#                         'American, 1958–1990',
#                         'Japanese',
#                         'American',
#                         'American',
#                         'Colombian',
#                         'American',
#                         'Mexican',
#                         'Italian',
#                         'Japanese',
#                         'American',
#                         'American',
#                         'American',
#                         'American',
#                         'Italian',
#                         'British',
#                         'france',
#                         'German',
#                         'france',
#                         'American',
#                         'British',
#                         'Hong Kong',
#                         'Canadian, 1952–2017',
#                         'American, 1927–1994',
#                         'Italian',
#                         'Follow',
#                         'Follow',
#                         'American',
#                         'Japanese',
#                         'Colombian',
#                         'American',
#                         'Austrian',
#                         'German',
#                         'American',
#                         'france',
#                         'NA',
#                         'Colombian-American',
#                         'American',
#                         'Follow',
#                         'British',
#                         'American',
#                         'American',
#                         'Chinese',
#                         'Australian',
#                         'American',
#                         'Japanese, 1903–1994',
#                         'Nigerian',
#                         'American',
#                         'Swedish',
#                         'British, 1876–1953',
#                         'Follow',
#                         'Irish',
#                         'American',
#                         'Swiss',
#                         'American',
#                         'Colombian-American',
#                         'American',
#                         'Follow',
#                         'NA',
#                         'American',
#                         'American',
#                         'Cuban',
#                         'Spanish, 1929–1999',
#                         'American',
#                         'Venezuelan',
#                         'American',
#                         'American',
#                         'NA',
#                         'Lithuanian',
#                         'British, 1802–1875',
#                         'American',
#                         'American'],
#  'authenticated': ['Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'NA',
#                    'Included',
#                    'Included'],
#  'classification': ['This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'Edition 255/289',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.',
#                     'This is a unique work.'],
#  'condition': ['Excellent',
#                'NA',
#                'NA',
#                'Excellent',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Excellent',
#                'NA',
#                'NA',
#                'New ',
#                'NA',
#                'Excellent',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Good, tear in the paper (see photo) does not affect the '
#                'drawing.',
#                'Excellent',
#                'NA',
#                'NA',
#                'NA',
#                'Pristine Condition',
#                'Https://www.artspacewarehouse.com/en/artist-clara-berta',
#                'Https://www.artspacewarehouse.com/en/artist-amber-goldhammer',
#                'Pristine Condition',
#                'Excellent',
#                'NA',
#                'Very good condition',
#                'Excellent',
#                'NA',
#                'NA',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-amber-goldhammer',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Good',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'Excellent',
#                'Excellent',
#                'Excellent',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-shauna-la',
#                'Good condition',
#                'NA',
#                'Perfect',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-bruce-rubenstein',
#                'NA',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'Good.',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'New',
#                'NA',
#                'NA',
#                'Slight discoloration along rim of pot',
#                'NA',
#                'Mint condition',
#                'Https://www.artspacewarehouse.com/en/artist-brandon-neher',
#                'NA',
#                'NA',
#                'New',
#                'In good conditions',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Excellent',
#                'NA',
#                'NA',
#                'The work is in perfect condition. It is framed behind '
#                'non-reflective glass with UV protection. ',
#                'Pristine Artist ',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-amber-goldhammer',
#                'Perfect',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-amber-goldhammer',
#                'NA',
#                'NA',
#                'Excellent',
#                'NA',
#                'Mint condition',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Perfect condition ',
#                'NA',
#                'Https://www.artspacewarehouse.com/en/artist-tommy-lennartsson',
#                'Good condition',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'Excellent Condition - Like New ',
#                'NA',
#                'Excellent',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'Excellent Condition - Like New',
#                'NA',
#                'NA',
#                'NA',
#                'Good condition',
#                'NA',
#                'New'],
#  'currency': ['$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '£',
#               '€',
#               '$',
#               '$',
#               '£',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '£',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '€',
#               '$',
#               '£',
#               '$',
#               '$',
#               '€',
#               '£',
#               '£',
#               '€',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '£',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '€',
#               '$',
#               '£',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '€',
#               '$',
#               '$',
#               '£',
#               '€',
#               '$',
#               '$',
#               '$',
#               '€',
#               '€',
#               '€',
#               'T',
#               '$',
#               '£',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '£',
#               '€',
#               '€',
#               '€',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '£',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '€',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '£',
#               '£',
#               '$',
#               '$',
#               '$',
#               '£',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '£',
#               '£',
#               '€',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '$',
#               '$',
#               '$',
#               '$',
#               '$',
#               '€',
#               '£',
#               '$',
#               '$'],
#  'framed': ['Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included',
#             'Included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Not included',
#             'Included',
#             'Included',
#             'Included'],
#  'gallery': ['Corridor Contemporary',
#              'Gallery 1261',
#              'Gallery 1261',
#              'Garvey | Simon',
#              'Luis De Jesus Los Angeles',
#              'Make offer',
#              'Mizuma & Kips',
#              'Gallery 1261',
#              'Gallery 1261',
#              'Make offer',
#              'New York',
#              'Gallery 1261',
#              'Garvey | Simon',
#              'Gallery 1261',
#              'New York',
#              'Make offer',
#              'Gallery 1261',
#              'Garvey | Simon',
#              'Gallery 1261',
#              'Gallery 1261',
#              'Gallery 1261',
#              'Make offer',
#              'Objets Trouvés',
#              'New York, NEW YORK',
#              'Mizuma & Kips',
#              'Provincetown',
#              'Provincetown',
#              'MTFA',
#              'Los Angeles, Zürich',
#              'Los Angeles, Zürich',
#              'MTFA',
#              'Garvey | Simon',
#              'Abend Gallery',
#              'Bakker Gallery',
#              'New York, NEW YORK',
#              'Abend Gallery',
#              'Newport Beach, Los Angeles , Palm Springs',
#              'Mizuma & Kips',
#              'Los Angeles, Zürich',
#              'Gallery 1261',
#              'Los Angeles, Zürich',
#              'Original Art Broker',
#              'West Chelsea Contemporary',
#              'Make offer',
#              'Make offer',
#              'Original Art Broker',
#              'Make offer',
#              'New York',
#              'Original Art Broker',
#              'Dep Art Gallery',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'West Chelsea Contemporary',
#              'Signari Gallery',
#              'Original Art Broker',
#              'Abend Gallery',
#              'Make offer',
#              'Ellen Miller Gallery',
#              'Ellen Miller Gallery',
#              'Garvey | Simon',
#              'Original Art Broker',
#              'Make offer',
#              'Make offer',
#              'Los Angeles, Zürich',
#              'Make offer',
#              'Mizuma & Kips',
#              'Make offer',
#              'West Chelsea Contemporary',
#              'Los Angeles, Zürich',
#              'Gallery 1261',
#              'Make offer',
#              'Make offer',
#              'Original Art Broker',
#              'Abend Gallery',
#              'Make offer',
#              'Make offer',
#              'MIAMI',
#              'Make offer',
#              'Hong Kong',
#              'Mizuma & Kips',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'HG Contemporary',
#              'Make offer',
#              'New York',
#              'Gallery Sitka',
#              'West Chelsea Contemporary',
#              '193 Gallery',
#              'Hal Bromm',
#              'Make offer',
#              'Graves International Art',
#              'Los Angeles, Zürich',
#              'Mutton Dressed as Lamb',
#              'West Chelsea Contemporary',
#              'The Art Design Project',
#              'Make offer',
#              'Abend Gallery',
#              'Gallery 1261',
#              'Original Art Broker',
#              'Original Art Broker',
#              'Los Angeles, Zürich',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'Gallery 1261',
#              'Make offer',
#              'Tinny Art House',
#              'West Chelsea Contemporary',
#              'Original Art Broker',
#              'Make offer',
#              'West Chelsea Contemporary',
#              'Make offer',
#              'Los Angeles, Zürich',
#              'Make offer',
#              'Mutton Dressed as Lamb',
#              'Los Angeles, Zürich',
#              'Make offer',
#              'Hamburger Kunstgalerie',
#              'New Haven',
#              'Make offer',
#              'Amy Simon Fine Art',
#              'JoAnne Artman Gallery',
#              'West Chelsea Contemporary',
#              'Make offer',
#              'Reem Gallery',
#              'Susan Eley Fine Art',
#              'New York',
#              'Art of Nature Contemporary',
#              'StolenSpace Gallery',
#              'Los Angeles, Zürich',
#              'Addison Rowe Gallery',
#              'Make offer',
#              'Susan Eley Fine Art',
#              'Los Angeles, Zürich',
#              'Make offer',
#              'Make offer',
#              'Make offer',
#              'MiXX projects + atelier',
#              'Make offer',
#              'David Leonardis Gallery',
#              'JoAnne Artman Gallery',
#              'Gebhardt Gallery',
#              'Original Art Broker',
#              'Inglewood',
#              'Original Art Broker',
#              'Gallery Sitka',
#              'JCamejo Art',
#              'Make offer',
#              'Original Art Broker',
#              'Make offer',
#              'Original Art Broker',
#              'QART.COM',
#              'Inglewood',
#              'Make offer',
#              'Make offer',
#              'San Francisco',
#              'Susan Eley Fine Art'],
#  'gallery_location': ['Tel-Aviv, Philadelphia',
#                       'Denver',
#                       'Denver',
#                       'New York',
#                       'Los Angeles',
#                       'THROWN',
#                       'new york',
#                       'Denver',
#                       'Denver',
#                       'THROWN',
#                       'Secure payment',
#                       'Denver',
#                       'New York',
#                       'Denver',
#                       'Secure payment',
#                       'After Nyne Contemporary',
#                       'Denver',
#                       'New York',
#                       'Denver',
#                       'Denver',
#                       'Denver',
#                       'Galerie Perahia',
#                       'Oklahoma City',
#                       'Secure payment',
#                       'new york',
#                       'Certificate of authenticity',
#                       'Certificate of authenticity',
#                       'Secure payment',
#                       'Certificate of authenticity',
#                       'Certificate of authenticity',
#                       'Secure payment',
#                       'New York',
#                       'Denver',
#                       'Provincetown',
#                       'Secure payment',
#                       'Denver',
#                       'Certificate of authenticity',
#                       'new york',
#                       'Certificate of authenticity',
#                       'Denver',
#                       'Certificate of authenticity',
#                       'Certificate of authenticity',
#                       'Austin , Lakeway, Austin',
#                       'Galerie Elisabeth & Klaus Thoman',
#                       'promoart21',
#                       'Certificate of authenticity',
#                       'THROWN',
#                       'Secure payment',
#                       'Certificate of authenticity',
#                       'Milan',
#                       'THROWN',
#                       'THROWN',
#                       'BABS Art Gallery',
#                       'Galerie Perahia',
#                       'Austin , Lakeway, Austin',
#                       'Certificate of authenticity',
#                       'Certificate of authenticity',
#                       'Denver',
#                       'THROWN',
#                       'Certificate of authenticity',
#                       'Certificate of authenticity',
#                       'New York',
#                       'Certificate of authenticity',
#                       'Galerie Elisabeth & Klaus Thoman',
#                       'Galerie Elisabeth & Klaus Thoman',
#                       'Certificate of authenticity',
#                       'Haynes Fine Art',
#                       'new york',
#                       'Bernard Jacobson Gallery',
#                       'Austin , Lakeway, Austin',
#                       'Secure payment',
#                       'Denver',
#                       'Lucia Mendoza',
#                       'SmART Coast Gallery',
#                       'Certificate of authenticity',
#                       'Denver',
#                       'Wallector',
#                       'BABS Art Gallery',
#                       'Certificate of authenticity',
#                       'Mimmo Scognamiglio / Placido',
# ...
#              '76.2 × 61 cm',
#              '50.5 × 40.5 cm',
#              '30.5 × 91.4 cm',
#              '139.7 × 139.7 cm',
#              '75.6 × 96.5 cm',
#              '34 cm',
#              '49 × 57 cm',
#              '81.3 × 152.4 cm',
#              '99.5 × 101 cm',
#              '55.9 × 50.8 × 3.8 cm',
#              '157.5 × 130.8 cm',
#              '207 × 121.9 × 3.8 cm',
#              '76.2 × 63.5 cm',
#              '76.2 × 55.9 cm',
#              '116.8 × 91.4 cm',
#              '27.9 × 35.6 × 2.5 cm',
#              '121.9 × 95.3 × 2.5 cm',
#              '42 × 30.5 cm',
#              '43.2 × 50.8 cm',
#              '62 × 49 cm',
#              '106.7 × 86.4 cm',
#              '57.2 × 76.2 cm',
#              '40.6 × 81.3 cm',
#              '122 × 190 × 2.5 cm',
#              '27.9 × 35.6 cm',
#              '58.4 × 78.7 cm',
#              '91.4 × 61 cm'],
#  'size_inches': ['36 × 54 in',
#                  '20 × 16 in',
#                  '16 × 20 in',
#                  '14 × 14 in',
#                  '60 × 54 in',
#                  '3 1/10 in',
#                  '74 4/5 × 74 4/5 in',
#                  '8 × 10 in',
#                  '50 × 40 in',
#                  '11 2/5 in diameter',
#                  '20 × 16 in',
#                  '14 × 11 in',
#                  '14 × 14 in',
#                  '16 × 20 in',
#                  '20 × 16 in',
#                  '63 × 63 in',
#                  '50 × 40 in',
#                  '17 × 28 in',
#                  '16 × 12 in',
#                  '24 × 30 in',
#                  '14 × 11 in',
#                  '17 7/10 in',
#                  '19 × 15 × 1 in',
#                  '9 3/8 × 16 1/2 in',
#                  '8 1/2 × 11 in',
#                  '12 × 36 × 1 in',
#                  '8 × 10 × 1 in',
#                  '8 × 6 × 2 in',
#                  '36 × 48 in',
#                  '18 × 18 in',
#                  '16 × 12 × 1 in',
#                  '17 × 14 in',
#                  '16 × 20 in',
#                  '14 1/4 × 22 1/2 in',
#                  '12 5/8 × 15 in',
#                  '36 × 24 in',
#                  '24 × 24 in',
#                  '110 × 100 in',
#                  '24 × 30 in',
#                  '30 × 24 in',
#                  '48 × 84 in',
#                  '22 × 22 in',
#                  '40 × 40 × 2 in',
#                  '51 1/5 in diameter',
#                  '39 2/5 × 39 2/5 in',
#                  '20 × 18 in',
#                  '7 1/10 × 5 9/10 in',
#                  '23 × 35 in',
#                  '49 × 60 in',
#                  '39 2/5 × 39 2/5 in',
#                  '16 1/2 × 11 7/10 in',
#                  '6 3/10 in diameter',
#                  '23 3/5 × 19 7/10 in',
#                  '17 7/10 in',
#                  '12 × 48 × 2 in',
#                  '24 × 9 in',
#                  '22 × 23 in',
#                  '9 31/50 × 10 87/100 × 1 31/50 in',
#                  '9 1/10 in',
#                  '41 × 29 in',
#                  '41 × 29 in',
#                  '8 × 8 in',
#                  '28 × 24 in',
#                  '139 4/5 in',
#                  '31 1/2 in diameter',
#                  '24 × 24 in',
#                  '31 3/4 × 25 3/4 in',
#                  '110 × 100 in',
#                  '13 1/2 × 17 1/2 × 7/10 in',
#                  '48 × 60 in',
#                  '48 × 48 in',
#                  '30 × 24 in',
#                  '22 4/5 × 16 9/10 in',
#                  '27 3/5 × 27 3/5 in',
#                  '24 × 20 in',
#                  '40 × 30 in',
#                  '4 9/10 × 3 1/10 in',
#                  '18 1/2 × 26 2/5 in',
#                  '22 × 18 in',
#                  '29 9/10 × 21 7/10 in',
#                  '28 7/10 × 52 2/5 in',
#                  '74 4/5 × 74 4/5 in',
#                  '39 2/5 × 55 1/10 in',
#                  '25 3/5 × 19 7/10 × 2 2/5 in',
#                  '21 × 24 1/4 in',
#                  '15 × 12 × 2 in',
#                  '16 1/2 in diameter',
#                  '20 × 16 in',
#                  '14 × 11 in',
#                  '10 × 8 in',
#                  '59 1/10 × 57 9/10 × 1/10 in',
#                  '7 × 7 1/2 × 4 1/2 in',
#                  '4 1/5 × 3 1/2 × 1/10 in',
#                  '36 × 36 in',
#                  '48 × 48 in',
#                  '16 × 12 in',
#                  '60 × 48 in',
#                  '30 × 40 × 2 in',
#                  '78 7/10 × 53 1/10 in',
#                  '32 × 38 in',
#                  '20 × 16 in',
#                  '28 × 24 in',
#                  '35 × 28 in',
#                  '48 × 36 in',
#                  '39 2/5 × 55 1/10 in',
#                  '14 3/5 in diameter',
#                  '57 1/2 × 44 9/10 × 2 in',
#                  '20 1/10 × 29 1/2 × 1 3/5 in',
#                  '63 × 51 1/5 × 2 in',
#                  '16 × 12 in',
#                  '29 9/10 × 22 4/5 in',
#                  '8 9/10 × 12 1/5 in',
#                  '21 1/2 × 15 in',
#                  '28 × 34 in',
#                  '55 1/10 × 63 in',
#                  '8 × 8 × 2 in',
#                  '7 1/2 × 8 7/10 in',
#                  '36 × 48 in',
#                  '4 1/5 × 3 1/2 × 1/10 in',
#                  '16 × 12 in',
#                  '18 × 18 in',
#                  '94 1/2 × 35 2/5 × 35 2/5 in',
#                  '43 3/10 × 43 3/10 × 4/5 in',
#                  '12 × 12 in',
#                  '36 3/5 × 28 7/10 × 2 in',
#                  '50 × 34 in',
#                  '81 1/2 × 61 1/2 in',
#                  '50 1/2 × 38 in',
#                  '12 1/5 in',
#                  '30 × 20 in',
#                  '14 1/2 × 14 1/2 in',
#                  '20 × 16 in',
#                  '15 7/10 × 7 9/10 in',
#                  '37 2/5 × 37 2/5 in',
#                  '28 × 22 in',
#                  '30 × 24 in',
#                  '19 9/10 × 15 9/10 in',
#                  '12 × 36 in',
#                  '55 × 55 in',
#                  '29 3/4 × 38 in',
#                  '13 2/5 in',
#                  '19 3/10 × 22 2/5 in',
#                  '32 × 60 in',
#                  '39 1/5 × 39 4/5 in',
#                  '22 × 20 × 1 1/2 in',
#                  '62 × 51 1/2 in',
#                  '81 1/2 × 48 × 1 1/2 in',
#                  '30 × 25 in',
#                  '30 × 22 in',
#                  '46 × 36 in',
#                  '11 × 14 × 1 in',
#                  '48 × 37 1/2 × 1 in',
#                  '16 1/2 × 12 in',
#                  '17 × 20 in',
#                  '24 2/5 × 19 3/10 in',
#                  '42 × 34 in',
#                  '22 1/2 × 30 in',
#                  '16 × 32 in',
#                  '48 × 74 4/5 × 1 in',
#                  '11 × 14 in',
#                  '23 × 31 in',
#                  '36 × 24 in'],
#  'title': ['Untitled "Pricilla"',
#            'Inner Dialogues',
#            'Meghan in Summer (Quarantine Nude) ',
#            'Uncommon Crow',
#            'Columbo',
#            'Miniature Pot | By Sophie Cohen',
#            'Poeti contropelo',
#            'Courtly',
#            'Brief Consideration (thoughts flew away)',
#            'Tideline 1 | By Simon Allen',
#            'Untitled (Drone Flower)',
#            'October Girl (Portrait in Fall)',
#            'Dried Grass',
#            'Susan in red',
#            'Untitled (Drone Flower)',
#            'Deep V',
#            'Consciousness and the Void',
#            'Altered States (double blue)',
#            'Pink and blue silhouette',
#            'Inner and Outer Space ',
#            'Danielle Outside',
#            'Wild Kong Rolling Stones',
#            "'In the Study - Self Portrait of Frida Kahlo,' charcoal drawing on "
#            'paper by Unknown (attributed to Frida Kahlo)',
#            'Cylinders',
#            'Dialogue (2)',
#            'Marginali',
#            'Widows Walk',
#            'Keys',
#            'Island Blue',
#            'Poppy Anne',
#            'Geo',
#            'Altered States (saffron)',
#            'Wrung',
#            'Study for Two Youths on Beach',
#            'Waves',
#            'Immersion',
#            'Informal Rhythm',
#            'Quattro Re (2)',
#            'Bubble Gum Flavor',
#            'The Invisible Object',
#            'Skyrocketing Love',
#            'PETER MAX ORIGINAL Ceramic Plate PAINTING Signed LIBERTY HEAD Pop '
#            'Art Acrylic',
#            'Field of Gold',
#            'Tensegrity Light',
#            'En atelier',
#            'Romero Britto Original Ink Drawing Hand Signed Elsa Benitez Sports '
#            'Illustrated',
#            'Concentrica XXIV | By Robert George',
#            'Sketch',
#            'Rob Douglas Large Original Acrylic Painting On Board Signed '
#            'Abstract Modern Art',
#            'Physichromie 1498',
#            'Intima | By Giulia Abbadessa',
#            'Ash Blue Footed Bowl | By Sylvie Joly',
#            'I OET E (me and you)',
#            'Wild Kong',
#            'Eventide I',
#            "'Tags' (pink-vertical)",
#            'PETER MAX Acrylic Painting ORIGINAL LIBERTY HEAD Signed Pop Art '
#            'Pastel Collage',
#            'In One Ear',
#            'Sake Set 1 | Steve Cook',
#            'Interval',
#            'Interval',
#            'Twin Ponds',
#            'PETER MAX Acrylic Painting ORIGINAL FLAG WITH HEART Signed POP ART '
#            'oil Love USA',
#            'the golden bar #2',
#            'The Uniform of the Private',
#            'Undulations 6',
#            'The Love Letter',
#            'Quattro Re (1)',
#            'Thanksgiving Day ',
#            'Virga Sunset',
#            'Bumble Bees',
#            'The Invisible Object',
#            'Sin título',
#            'Fragile soul X',
#            'Robert Philipp Rare Original Painting Oil On Board Signed Portrait '
#            'Artwork SBO',
#            'Wonderland',
#            'Figure in Mask',
#            'I OET E (me and you)',
#            'Fatale',
#            'Blood Orange',
#            'The Eternal Flame',
#            'Lo sono la lotta',
#            'SE IL AMI AC UR A (Sei La Mia Cura - You Are My Cure)',
#            'Les prisons mentales',
#            'Carmen Oval Head with Dividing Line (Plate XXIX)',
#            'Untitled ',
#            'MoonJar | By Tarragon Smith',
#            'Untitled (Drone Flower)',
#            '"Jenga"',
#            'Untitled',
#            'Cartographies Humaines',
#            'Untitled (Flower pot and saucer)',
#            'Flower',
#            'Audrey Hepburn Icon VIII',
#            '576 Circles',
#            'The Keeper',
#            'The Inevitable',
#            '"104" from La transvaloración de todos los valores.',
#            'Vestito',
#            'Entrance and Sun',
#            'Girl in Red and Black',
#            'PETER MAX Acrylic Painting ORIGINAL UMBRELLA MAN Signed ART ICONIC '
#            'oil Large',
#            'Mark Di Suvero Original Watercolor Painting Hand Signed Framed Art '
#            'Sculpture',
#            'As A Dream Upon Waking',
#            'AB BIC URAD IT E (Abbi Cura Di Te - Take Care of Yourself)',
#            'Cirrus 1 | By Simon Allen',
#            'blue Paname',
#            'Samara Jati',
#            'Les raies volantes',
#            'Study of Morgan',
#            'Untitled (Dioxazine mauve)',
#            'Sumo Wrestler',
#            'Shadow Head ',
#            'Edward Kienholz Original Oil Painting On Board Signed Large '
#            'Carousel Horse Art',
#            'Salon de Musique ',
#            'By The Inlet',
#            'Concentrica XX | By Robert George',
#            'Love Jungle',
#            'Flower',
#            'Hive',
#            'Jackson George',
#            'bone #5',
#            'Frau mit Gitarre',
#            'Fortune Teller',
#            'la cuisinière',
#            'Red Petals',
#            'Persephone',
#            'Keep On Keepin On',
#            'Amphora | By Tarragon Smith',
#            'I Painted Virgil So We Can Be Internet Friends',
#            'Run Away!',
#            'Untitled (Drone Flower)',
#            'Lotus Pond 1 (Vertical) 荷塘清趣 一（豎）',
#            'Burger King',
#            'Free Pancakes',
#            'Golden Echo',
#            'Blue Somadina ',
#            'Airplane',
#            'How Do You Match Light Blue Shoes?',
#            'Farmyard Friends',
#            'Lichen and Peat Moon Jar | By Patricia Millar',
#            'Hawk Block 1',
#            'Lucky Strike',
#            'Série de Mars 2020 nº4',
#            'Casper #1',
#            'The Whistle',
#            'In The Middle Of The Fray',
#            'Ruth Schloss Original Acrylic Painting Signed Female Portrait '
#            'Artwork Authentic',
#            'Suit for my Birthday',
#            'Jim Dine Watercolor Painting Original Signed Large Child Self '
#            'Portrait Artwork',
#            'Study in Blue #2',
#            'Brief contact with the elemental” – 2014 – Acrylic on canvas – 48” '
#            'x 37 ½”',
#            'Untitled',
#            'PETER MAX all Original PAINTING POP ART PROFILES Watercolor SIGNED '
#            'Pop Art Rare',
#            'Constructivo A',
#            'PETER MAX Original Acrylic PAINTING on CANVAS Signed SAGE with '
#            'CANE Art LARGE',
#            'Behold Eternal Love',
#            'That shit that got me sick that one time',
#            'Ding Dong! Avon Calling!',
#            'Shipping off the Coast',
#            'Sibyls',
#            'Rococo Modo'],
#  'year': ['ca. 2012',
#           '2020',
#           '2020',
#           '2008',
#           'II',
#           '2020',
#           '2020',
#           '2020',
#           '2020',
#           '2020',
#           '2018',
#           '2020',
#           '2000',
#           'white',
#           '2018',
#           '2019',
#           '2018',
#           '2020',
#           '2018',
#           '2016',
#           '2020',
#           '2020',
#           '20th century',
#           '2020',
#           '2020',
#           '2013',
#           '2021',
#           '2018-2020',
#           '2020',
#           '2020',
#           '2018-2020',
#           '2020',
#           '2021',
#           '1948',
#           '2020',
#           '2020',
#           '2021',
#           '2020',
#           '2020',
#           '2020',
#           '2020',
#           '1990-1999',
#           '2020',
#           '1999-2020',
#           '2017',
#           '2002',
#           '2020',
#           '2019',
#           '2002',
#           '2007',
#           '2020',
#           '2020',
#           '2018',
#           '2020',
#           '2018',
#           '2019',
#           '1990-1999',
#           'Out the Other',
#           '2020',
#           '2019',
#           '2019',
#           '2020',
#           '21st Century',
#           '2020',
#           '2020',
#           '2020',
#           '19th Century',
#           '2020',
#           '1973',
#           '2019',
#           '2020',
#           '2020',
#           '2016',
#           '2021',
#           '20th Century',
#           '2021',
#           '20th Century',
#           '2020',
#           '2019',
#           '2016',
#           '2020',
#           '2020',
#           '2018',
#           '2015',
#           '1949',
#           '1987',
#           '2020',
#           '2018',
#           '2020',
#           '2019',
#           'densité',
#           '1982',
#           '2006-2009',
#           '2021',
#           '2020',
#           '2019',
#           '2020',
#           '2021',
#           '2015',
#           '2021',
#           '2018',
#           '21st Century',
#           '20th Century',
#           '2020',
#           '2018',
#           '2020',
#           '2020',
#           '2020',
#           '2020',
#           '2019',
#           '2020',
#           '2020',
#           '1984-1994',
#           '20th Century',
#           '2015',
#           '2020',
#           '2020',
#           '2020',
#           '2006-2009',
#           '2020',
#           '2020',
#           '2020',
#           '2011',
#           '2018',
#           '2020',
#           '2021',
#           '2020',
#           '2018',
#           '2020',
#           '2019',
#           '2019',
#           '2018',
#           '2020',
#           '2015',
#           '2015',
#           'Unknown',
#           '2020',
#           '2015',
#           '2020',
#           '19th Century',
#           '2020',
#           '2020',
#           '2021',
#           '2020',
#           '1990',
#           '2020',
#           '2021',
#           '20th Century',
#           '2020',
#           '1996',
#           '2017',
#           '2014',
#           '1948',
#           '1970-1989',
#           '2020',
#           '1974',
#           '2000-2020',
#           '2020',
#           '2020',
#           '19th Century',
#           '2019',
#           '2016-2017']}

# %%
# write the links file to a separate .txt file for backup
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-fa2a1e461dc7> in <module>
#       1 # write the links file to a separate .txt file for backup
#       2 import pandas as pd
# ----> 3 df = pd.DataFrame(data)
#       4 df.to_csv()
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### 3A. Attempt a quicker solution with Beautiful Soup

# %%
import requests
import urllib3
from bs4 import BeautifulSoup

URL = "https://www.artsy.net/artwork/karl-hartman-uncommon-crow"
http = urllib3.PoolManager()

response = http.request('GET', URL)
soup = BeautifulSoup(response.data, "lxml")

image_URL = soup.img['src']
print(image_URL)

sidebar = driver.find_element_by_xpath('//div[@data-test="artworkSidebar"]').text.split("\n")
    data["image_URL"].append(image_URL)
    data["artist"].append(sidebar[0])
    data["title"].append(sidebar[2].split(", ")[0])
    data["year"].append(sidebar[2].split(", ")[1])
    data["medium_details"].append(sidebar[3])
    data["size_inches"].append(sidebar[4])
    data["size_cm"].append(sidebar[5])
    data["classification"].append(sidebar[6])
    data["currency"].append(sidebar[7][0:1])
    data["price"].append(sidebar[7][1:])
    data["gallery"].append(sidebar[12])
    data["gallery_location"].append(sidebar[13])
# Out:
# https://d32dm0rphc51dk.cloudfront.net/Av-Aaqu_JwskxttJT4z_Vg/large.jpg

# %% [markdown]
# ### 3B. Attempt a quicker solution with Scrapy

# %%
import scrapy

class ImageSpider(scrapy.Spider):

    name: 'images'

    def start_requests(self):
        urls = [
            'https://www.artsy.net/artwork/karl-hartman-uncommon-crow'
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
    
    def parse(self, response):
        page = response.

# %% [markdown]
# ### 3C. Attempt a quicker solution with the Artsy API

# %%
## API solution

import requests

headers = {'X-Auth-Token': 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MDE0NDk3MjNlZjg1MjAwMTE3YTBiNGUiLCJleHAiOjE2MTI1NDcwNTksImlhdCI6MTYxMTk0MjI1OSwiYXVkIjoiNjAxNDQ5NzIzZWY4NTIwMDExN2EwYjRlIiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYwMTQ0OTczODNkMmEyMDAxMTFjZDBiNiJ9.Jb7HeMLSEsdEO69PxqM80B4pEqGqxPzFg2cYUE9TfyI'}

r = requests.get("https://api.artsy.net/api/sales", headers=headers)
r.json()

# %% [markdown]
# ### 4. Clean the data in Pandas

# %%
import pandas as pd
